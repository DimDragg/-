# %% [markdown]
# <a href="https://colab.research.google.com/github/DimDragg/-/blob/main/%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0_%D1%80%D0%BE%D0%B1%D0%BE%D1%82%D0%B0_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Лабораторна робота 7. Чуркін Дмитро, ФІТ 3-15

# %% [markdown]
# Був присутній на парі

# %% [markdown]
# Завдання 1. Розв'язати задачу класифікації для датасета Врятувати принцесу
#
# Завдання 2.Побудувати модель Метод опорних векторів і дерево рішень. Порівняти результати, вибрати найкращу модель.

# %%
import pandas as pd
import numpy as np
import os

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score

#Я вставив оба Завдання в один код
# 1. Пошук та завантаження CSV
print("Файли:", os.listdir())

file_name = [f for f in os.listdir() if f.endswith("data.csv")][0]
print("Використовуємо файл:", file_name)

df = pd.read_csv(file_name)

print("\nПерші рядки:")
print(df.head())

# 2. Передобробка
df = df.drop_duplicates()

print("\nПерепустки:")
print(df.isnull().sum())

df = df.fillna(df.mean(numeric_only=True))

# 3. Кодування категоріальних даних
le = LabelEncoder()

for col in df.select_dtypes(include='object').columns:
    df[col] = le.fit_transform(df[col])

# 4. Поділ даних
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# 5. МОДЕЛЬ 1 — SVM
svm = SVC()
svm.fit(X_train, y_train)

y_pred_svm = svm.predict(X_test)

print("\n SVM")
print("Accuracy:", accuracy_score(y_test, y_pred_svm))
print(classification_report(y_test, y_pred_svm))

# 6. МОДЕЛЬ 2 — Decision Tree
tree = DecisionTreeClassifier(max_depth=5)
tree.fit(X_train, y_train)

y_pred_tree = tree.predict(X_test)

print("\n Decision Tree")
print("Accuracy:", accuracy_score(y_test, y_pred_tree))
print(classification_report(y_test, y_pred_tree))

# 7. Порівняння моделей
acc_svm = accuracy_score(y_test, y_pred_svm)
acc_tree = accuracy_score(y_test, y_pred_tree)

print("\n Порівняння")
print("SVM:", acc_svm)
print("Decision Tree:", acc_tree)

if acc_svm > acc_tree:
    print("Найкраща модель: SVM")
else:
    print("Найкраща модель: Decision Tree")
# Out:
# Файли: ['.config', 'data.csv', 'sample_data']
# Використовуємо файл: data.csv
#
# Перші рядки:
#    Phoenix Feather  Unicorn Horn  Dragon's Blood  Mermaid Tears  Fairy Dust  \
# 0              2.4          18.7            18.4           27.9         7.9
# 1              2.1           6.0            15.0           13.3        15.6
# 2             17.2          13.9            23.8            6.8        10.7
# 3              8.4           9.7             6.8           26.9         4.6
# 4             22.1          10.8            16.4           10.5        22.0
#
#    Goblin Toes  Witch's Brew  Griffin Claw  Troll Hair  Kraken Ink  \
# 0          9.6          18.3          13.2         2.5        26.0
# 1         13.1          11.0           5.0         7.2        26.0
# 2         15.8          19.4           2.7        15.4        21.2
# 3         29.1          14.6          19.7        18.0        20.8
# 4         23.4           2.6          18.2        23.8        11.3
#
# ...

# %% [markdown]
# Висновки:
#
# У ході виконання лабораторної роботи було розв’язано задачу класифікації на основі датасету «Cure the Princess». Було проведено попередню обробку даних: перевірено наявність пропущених значень та дублікатів, виконано їх усунення, а також закодовано категоріальні ознаки у числовий формат.
#
# Дані було розділено на тренувальну та тестову вибірки, після чого побудовано дві моделі класифікації: метод опорних векторів (SVM) та дерево рішень (Decision Tree).
#
# За результатами навчання та тестування моделей було обчислено метрики якості, зокрема точність (accuracy) та інші показники класифікації. Порівняння результатів показало, що одна з моделей продемонструвала кращу узагальнюючу здатність на тестових даних.
#
# Загалом, метод опорних векторів забезпечує більш стабільні результати при складних межах розділення, тоді як дерево рішень є більш інтерпретованим, але може бути схильним до перенавчання.
